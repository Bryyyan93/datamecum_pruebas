# %%
import pandas as pd

# %%
# Ejercicio 1
# Crea una Series llamada poblacion_estimada con estos datos:

poblacion_estimada = pd.Series({
    "Ohio": 35000,
    "Texas": 71000,
    "Oregon": 16000,
    "Utah": 5000
})
print(type(poblacion_estimada))
'''
Muestra la serie entera.
Muestra los índices de la serie.
Muestra los valores de la serie.
Muestra el valor asociado a "Texas".
'''
print(poblacion_estimada)
print(poblacion_estimada.index)
print(poblacion_estimada.values)
print(poblacion_estimada["Texas"])
# Out:
# <class 'pandas.core.series.Series'>
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64
# Index(['Ohio', 'Texas', 'Oregon', 'Utah'], dtype='object')
# [35000 71000 16000  5000]
# 71000

# %%
'''Ejercicio 2

Usando la serie poblacion_estimada del ejercicio anterior:

Filtra y muestra solo los estados con población mayor que 20000.

Calcula una nueva serie donde cada valor sea un 10% más alto (multiplica por 1.1).

Calcula una nueva serie con cada valor elevado al cuadrado.

'''

filtro_grandes = poblacion_estimada > 20000
print(filtro_grandes.index)
# Out:
# Index(['Ohio', 'Texas', 'Oregon', 'Utah'], dtype='object')

# %%
fertility = pd.read_csv("programas/data/children_per_woman_total_fertility.csv", sep = ",")
mortality = pd.read_csv("programas/data/child_mortality_0_5_year_olds_dying_per_1000_born.csv", sep = ",")

print(fertility)
print(mortality)
# Out:
#      geo          name  1800  1801  1802  1803  1804  1805  1806  1807  ...  \
# 0    afg   Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00  ...
# 1    ago        Angola  6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94  ...
# 2    alb       Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60  ...
# 3    and       Andorra  2.11  2.11  2.11  2.11  2.11  2.11  2.11  2.11  ...
# 4    are           UAE  6.94  6.94  6.94  6.94  6.94  6.94  6.94  6.94  ...
# ..   ...           ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 190  wsm         Samoa  6.98  6.98  6.98  6.98  6.98  6.98  6.98  6.98  ...
# 191  yem         Yemen  6.88  6.88  6.88  6.88  6.88  6.88  6.88  6.88  ...
# 192  zaf  South Africa  6.47  6.47  6.47  6.47  6.47  6.47  6.47  6.47  ...
# 193  zmb        Zambia  6.71  6.71  6.71  6.71  6.71  6.71  6.71  6.71  ...
# 194  zwe      Zimbabwe  6.75  6.75  6.75  6.75  6.75  6.75  6.75  6.75  ...
#
# ...
