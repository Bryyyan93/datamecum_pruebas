# %%
import pandas as pd

# %%
maquina = pd.read_csv("./PrediccionesMaquina.csv")
maquina.sample(10)
# Out:
#       tipo      matricula         dia         a1   a2          a3          a4  \
# 67541   01  Máquina_ID292  2016-03-14   0.986032  0.0    5.766903   14.687617
# 38733   01  Máquina_ID179  2016-02-22  12.734746  0.0   51.965692  107.227074
# 44419   01  Máquina_ID200  2016-02-10   5.607619  0.0   11.623274   81.153155
# 18902   01   Máquina_ID93  2016-07-10   0.000000  0.0  110.220483  161.983238
# 4482    01   Máquina_ID20  2016-07-20  11.163509  0.0    0.854505    1.757005
# 38098   01  Máquina_ID177  2016-02-29   0.000000  0.0    2.876827    3.935753
# 74313   02  Máquina_ID321  2016-06-28   0.000000  0.0    0.993730    3.993533
# 64014  NaN  Máquina_ID279  2016-01-29        NaN  NaN         NaN         NaN
# 13877   01   Máquina_ID69  2016-10-24  12.552170  0.0    4.514071    0.000000
# 54433   01  Máquina_ID237  2016-02-29   0.000000  0.0   10.138772    0.000000
#
#         a5        a6   a7  ...  a39  a43  a44  a45  a46       a200      a201  \
# ...

# %%
maquina["matricula"].unique().tolist()
# Out:
# ['Máquina_ID1',
#  'Máquina_ID2',
#  'Máquina_ID3',
#  'Máquina_ID4',
#  'Máquina_ID5',
#  'Máquina_ID6',
#  'Máquina_ID7',
#  'Máquina_ID8',
#  'Máquina_ID9',
#  'Máquina_ID10',
#  'Máquina_ID11',
#  'Máquina_ID12',
#  'Máquina_ID13',
#  'Máquina_ID14',
#  'Máquina_ID15',
#  'Máquina_ID16',
#  'Máquina_ID17',
#  'Máquina_ID18',
#  'Máquina_ID19',
#  'Máquina_ID20',
#  'Máquina_ID21',
#  'Máquina_ID22',
#  'Máquina_ID23',
#  'Máquina_ID24',
#  'Máquina_ID25',
#  'Máquina_ID26',
#  'Máquina_ID27',
#  'Máquina_ID28',
#  'Máquina_ID29',
#  'Máquina_ID30',
#  'Máquina_ID31',
#  'Máquina_ID32',
#  'Máquina_ID33',
#  'Máquina_ID34',
#  'Máquina_ID35',
#  'Máquina_ID36',
#  'Máquina_ID37',
#  'Máquina_ID38',
#  'Máquina_ID39',
#  'Máquina_ID40',
#  'Máquina_ID41',
#  'Máquina_ID42',
#  'Máquina_ID43',
#  'Máquina_ID44',
#  'Máquina_ID45',
#  'Máquina_ID46',
#  'Máquina_ID47',
#  'Máquina_ID48',
#  'Máquina_ID49',
#  'Máquina_ID50',
#  'Máquina_ID51',
#  'Máquina_ID52',
#  'Máquina_ID53',
# ...

# %%
maquina.columns
# Out:
# Index(['tipo', 'matricula', 'dia', 'a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7',
#        'a8', 'a9', 'a10', 'a11', 'a12', 'a13', 'a16', 'a17', 'a18', 'a19',
#        'a20', 'a21', 'a22', 'a23', 'a24', 'a25', 'a26', 'a27', 'a28', 'a29',
#        'a30', 'a31', 'a32', 'a33', 'a34', 'a35', 'a36', 'a37', 'a38', 'a39',
#        'a43', 'a44', 'a45', 'a46', 'a200', 'a201', 'a202', 'a203', 'p_orden'],
#       dtype='object')

# %%
alarmas = maquina.loc[:, "a1":"a203"].columns.to_list()
alarmas
# Out:
# ['a1',
#  'a2',
#  'a3',
#  'a4',
#  'a5',
#  'a6',
#  'a7',
#  'a8',
#  'a9',
#  'a10',
#  'a11',
#  'a12',
#  'a13',
#  'a16',
#  'a17',
#  'a18',
#  'a19',
#  'a20',
#  'a21',
#  'a22',
#  'a23',
#  'a24',
#  'a25',
#  'a26',
#  'a27',
#  'a28',
#  'a29',
#  'a30',
#  'a31',
#  'a32',
#  'a33',
#  'a34',
#  'a35',
#  'a36',
#  'a37',
#  'a38',
#  'a39',
#  'a43',
#  'a44',
#  'a45',
#  'a46',
#  'a200',
#  'a201',
#  'a202',
#  'a203']

# %%
alarm = "a1"
matri = "Máquina_ID17"

print(maquina.loc[maquina["matricula"] == matri, ["dia", alarm]])
# Out:
#              dia   a1
# 3871  2016-01-07  0.0
# 3872  2016-01-08  0.0
# 3873  2016-01-11  0.0
# 3874  2016-01-12  0.0
# 3875  2016-01-13  0.0
# ...          ...  ...
# 4077  2016-12-02  0.0
# 4078  2016-12-07  0.0
# 4079  2016-12-09  0.0
# 4080  2016-12-12  0.0
# 4081  2016-12-13  0.0
#
# [211 rows x 2 columns]

# %%
#print(maquina.loc[maquina["matricula"] == matri])
filtro = maquina.loc[maquina["matricula"] == matri]
print(filtro.loc[:,"a1":"a203"])
# Out:
#        a1   a2        a3        a4        a5        a6   a7        a8   a9  \
# 3871  0.0  0.0  1.748991  2.860993  0.000000  8.036727  0.0  0.922830  0.0
# 3872  0.0  0.0  1.738026  2.851741  0.000000  7.991544  0.0  0.920278  0.0
# 3873  0.0  0.0  1.727129  2.842519  0.000000  7.946614  0.0  0.917733  0.0
# 3874  0.0  0.0  1.716301  2.833328  0.000000  7.901938  0.0  0.915195  0.0
# 3875  0.0  0.0  1.705540  2.824165  0.000000  7.857512  0.0  0.912664  0.0
# ...   ...  ...       ...       ...       ...       ...  ...       ...  ...
# 4077  0.0  0.0  0.000000  0.000000  0.954859  0.000000  0.0  0.000000  0.0
# 4078  0.0  0.0  0.000000  0.000000  0.940270  0.000000  0.0  0.000000  0.0
# 4079  0.0  0.0  0.000000  0.000000  0.925904  0.000000  0.0  0.000000  0.0
# 4080  0.0  0.0  0.000000  0.000000  0.911757  0.000000  0.0  0.000000  0.0
# 4081  0.0  0.0  0.000000  0.000000  0.897826  0.000000  0.0  0.000000  0.0
#
# ...
